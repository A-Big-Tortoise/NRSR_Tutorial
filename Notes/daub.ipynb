# %%
import numpy as np
import scipy
import random
import matplotlib.pyplot as plt


# ind = random.randint(17, 34)
for ind in range(17, 35):
    plt.figure()
    cardiac_s = scipy.signal.wavelets.daub(ind)
# cardiac_d = scipy.signal.wavelets.daub(ind)*0.3*diastolic/80 # change height to 0.3
    plt.plot(cardiac_s)
    plt.show()
# Out:
# C:\Users\86189\AppData\Local\Temp\ipykernel_2768\3469576233.py:10: DeprecationWarning: Please use `daub` from the `scipy.signal` namespace, the `scipy.signal.wavelets` namespace is deprecated.
#   cardiac_s = scipy.signal.wavelets.daub(ind)
